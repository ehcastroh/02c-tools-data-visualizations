# %% [markdown]
# <!--![data-x](http://oi64.tinypic.com/o858n4.jpg)-->
#
# <div align="center"><img src= "http://oi64.tinypic.com/o858n4.jpg" align="center" width="100%"></div>
#
# <br>
#
# </br>
#
#
# # __Introduction to Data Visualization in Python__
#
# **Author list:** Alexander Fred Ojala, and Elias Castro Hernandez
#
# **Main Reference(s):** Stanfords's CS 448B - Data Visualization Techniques Class (see Appendix I), and pretty much everything by Edward Tufte.
#
# **Copright:** Feel free to do whatever you want with this code.
# <hr style="border: 8px solid#0B0B0B;" />

# %% [markdown]
# <br>
#
# ## Data Visualization with Matplotlib, Seaborn, and Plotly.
#
# Matplotlib is the standard plotting library in Python. It is well tested, well maintained and it has been around since ~2003. It also has a great support community.
#
# Matplotlib is highly customizable and sometimes it takes a lot of code to make a plot look like you want. It would take over a semester to go through all of the commands and aspects in matplotlib, therefore this notebook only works as a gentle introduciton.
#
# Many other plotting libraries (like `seaborn, pandas, bokeh, plotly, ` etc.) are built on top / integrates well with matplotlib. Therefore, it is an important package to know.

# %% [markdown]
# ### Table of Contents
#
# > #### [Part 1: Matplotlib](#Part_1)
#
# > #### [Part 2: Seaborn](#Part_2)
#
# > #### [Part 3: Plotly](#Part_3)
#
#
# ### Additional Material
#
# > #### [Appendix I: Resources and references to material we won't cover in detail](#Appendix_I)
#
# > #### [Appendix II: Gallery of visualization examples](#Appendix_II)

# %% [markdown]
# <a id='Part_1'></a>
# <hr style="border: 3px solid#0B0B0B;" />
#
# ## **Part 1: Matplotlib**
#
# **General Information**
#
# > 1. __Load Matplotlib:__ https://matplotlib.org/faq/installing_faq.html#installation
#
# > 2. __Matplotlib Object Hierarchy:__ https://matplotlib.org/tutorials/introductory/usage.html
#
# > 3. __Approaches to Matplotlib__

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ## 1.1 - Load matplotlib

# %%
# Standard way to import matplotlib from scratch: import matplotlib.pyplot as plt
# you might also see import pylab, however the procedure below is preferred

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt  # always import pyplot module as plt (standard)

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ## 1.2 - Matplotlib Object Hierarchy

# %% [markdown]
# <div align="center">
#     <img src= "https://files.realpython.com/media/fig_map.bc8c7cabd823.png" align="center" width='400px'>
#
#     https://realpython.com/python-matplotlib-guide/
# </div>

# %% [markdown]
# **Figure**
#
# > Outermost container for a matplotlib graphic.
#
# > Can contain multiple Axes objects.
#
# **Axes**
#
# > Actual plots
#
# > Each axes contains smaller objects such as tick marks, individual lines, legends, and text boxes.
#
# **Artist**
#
# > Everything you can see on the figure is an artist, including Figure, Axes, Axis-objects, text-object, etc.
#
# > Most Artists are tied to an Axes -- an Artist cannot be shared by, or moved from one to another, Axes

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ## 1.3 - Two plotting approaches
#
# There are two approaches to plotting:
# 1. **The functional / MATLAB approach (non-pythonic)**
# >https://matplotlib.org/tutorials/introductory/pyplot.html
#
# > Most Common way of using matplotlib.
#
# > It is not pythonic, relies on global functions, and displays global figures.
#
# > Easy approach for interactive use.
#
# > Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.
#
# >

# %% [markdown]
# 2. **Object-oriented approach (Pythonic is preferred)**
# > https://matplotlib.org/tutorials/introductory/lifecycle.html
#
# > Pythonic is object oriented.
#
# > You obtain an empty figure from a global factory and build plots explicityly using methos of the figure and classes it contains.
#
# >
#
# <br>

# %% [markdown]
# <hr style="border: 2px solid#0B0B0B;" />
#
# ### **1.3.1 - The Functional / MATLAB Approach (non-pythonic)**

# %% [markdown]
# **Note that the command:**
# ``` python
# plt.plot(x,y)
# ```
# will create a `figure object` ( the canvas that we plot on ) and an `axes object` that is the plot with lines and info.

# %%
type(plt.plot()) # plt.plot() creates empty plot, semi colon suppresses text output
# Out:
# list

# %%
#explore attributes
#dir(plt.plot())

# %% [markdown]
# ___
# ### Simple Line Plot

# %%
plt.plot([1,2,3])
plt.ylabel('Numbers')
plt.xlabel('where did these come from?')
plt.show()  # Note: we don't have to run plt.show() if we have run  %matplotlib inline  once in the kernel session

"""Note: if plot() receives only a single list/array of data, matplotlib assumes it is a sequence of y-values and automatically genereates the x-values"""
# Out:
# 'Note: if plot() receives only a single list/array of data, matplotlib assumes it is a sequence of y-values and automatically genereates the x-values'

# %% [markdown]
# ___
#
# ### Compound Lines
#
# > __Key Concept:__ any compount plot requires that each 'input' be of the same dimension/length

# %%
# Simple plot of two lists, x versus y, plt.plot(x,y, color_type)
# note that they are of equal length

plt.plot([1,2,3,4],[-1,1,4,8]) # elements of list form an ordered pair
plt.axis([0,5,0,6])            # [x_start, x_stop, y_start, y_stop] specifies the viewport of the axes
plt.show()

# %% [markdown]
# >**Note:** The letters and symbols of the format string are taken from MATLAB -- you concatenate a color string with a line style string. E.g. 'bo' := blue o's

# %% [markdown]
# ___
# ### Plot 100 Random Numbers For **Three Categories From A Numpy Array**

# %%
# every new cell where you run plt.plot() will create a new figure
N = 100 
x = np.arange(1,N+1)
y = np.random.randn(N)

# red dashes, blue squares and green triangles
plt.plot(x, y, 'r--', x, y**2, 'bs', x, y**3, 'g^')
plt.axis([0,100,0,15])
plt.show()

# %% [markdown]
# ___
# ### Plotting From **Pandas Dataframes**

# %%
# if plt.plot(*args) are run in the same cell, they will plot on the same axes

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# **Note that the command:**
# ``` python
# dir(plt)
# ```
# will display all the available 'attributes' and 'functions' for the plt object
#
# >**More info** - https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# ___
# ### New Plot, One Cell (i.e. Same Figure, New Axes)
# `plt.figure()` creates a new figure in the same cell

# %%
# if plt.plot(*args) are run in the same cell
# we will plot on the same axes

# Scaterplot
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.figure() 

# Bars
plt.hist('a')  # Note: same method/function is plotted on same figure
plt.hist('b'); # semicolon supreses text of object details

# %% [markdown]
# ___

# %%
x = np.linspace(0, 1, 100)
# lines
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Three Lines")  # note the ordering of color by matplotlib


plt.legend();

# %% [markdown]
# ___
# ### Combine Line & Scatter Plots From **Categorical Variables**

# %%
names = ['grade_a', 'grade_b', 'grade_c', 'grade_d', 'grade_f']
values = [10, 30, 20, 8, 3]

plt.plot(names,values, 'm-')
plt.scatter(names, values);

# %% [markdown]
# ___
# ### Line & Scatter Plot With Annotations

# %%
plt.plot(names,values,marker='*')
plt.text('grade_c', 30, r'$grade=b,\ students=30$')  # (location_y, location_x, *args)
#xy := location being annotated
# xytext := location to place the text
plt.annotate('local max', xy=('grade_b', 30), xytext=(3, 20),
             arrowprops=dict(facecolor='magenta', shrink=0.0005),
             );

# %% [markdown]
# ___
# ### Histograms, Scatter & Line Plots Using **Subplots**

# %% [markdown]
# **Note that the command:**
# ``` python
# plt.subplot(*args)
# ```
# will create an `axes.SubplotBase`.
# >**For more info** - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html#matplotlib.pyplot.subplot

# %%
plt.figure(1, figsize=(16, 3)) # layout and label-dimensions for plots

plt.subplot(132)       # num_rows|num_cols|position
plt.title('Data-X Grades\n\n')
plt.bar(names, values)
plt.subplot(131)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle(r'$Categorical \ Plotting: C\left(Obj(x),\ f:x\longrightarrow y \right)$');  # TeX in plots

# automatically space subplots 
#plt.tight_layout()

# %% [markdown]
# ___
# ### Multiple **Subplots With Nonlinear Axes & Variable Spacing**

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

plt.figure(1, figsize=(8,6)) # layout and label-dimensions for plots

# Fixing random state for reproducibility
np.random.seed(0)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log with no grids
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(False)


# symmetric log with no frame
plt.subplot(223, frameon=False)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit clean plot and in oragne
plt.subplot(224,facecolor='red')  # Note: facecolor requires frameon=True
plt.plot(x, y, color = 'white')
plt.yscale('logit')
plt.title('logit')
plt.grid(False)

# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())

# Adjust the subplot layout manually
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.65,
                    wspace=0.65)

# OR automatically space subplots 
#plt.tight_layout()

# %% [markdown]
# <hr style="border: 2px solid#0B0B0B;" />
#
# ## **1.3.2 - Object-Oriented (OO) Approach (Pythonic is preferred)**
# The object-oriented approach is more powerful and should be used when you want more control of your visualization. Instead of letting matplotlib handle what figure and axes that is the current one, we assign the `figure (the final image that may contain one or more axes)` and `axes (the individual plot)` objects to variables and apply functions via methods on them.
#
# <br>

# %% [markdown]
# <div align="center">
#     <img src= "https://matplotlib.org/_images/anatomy.png" align="center" width='600px'>
#
#     https://matplotlib.org/examples/showcase/anatomy.html
# </div>

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### Simple Line Plot(s)
#
# - The **Figure** is the final image and may contain one or more Axes.
# - The **Axes** represent individual plot(s)

# %%
# f is the canvas object, can contain several plots i.e. axes objects (p)
f, ax = plt.subplots() # returns tuple:

group_mean = np.mean(values)/4

# Add a horizontal line denoting average
ax.axhline(group_mean, ls='--', color='r')

ax.plot([1,2,3,4],[5,2,8,7]);
ax.hist(np.random.randint(1,4,10));

# %% [markdown]
# ___

# %%
# Another approach, only create figure, then add subplots

f = plt.figure()
ax = f.add_subplot(1,1,1) # add subplot at location 1,1,1
# same as: ax = f.add_subplot(111)
ax.plot([1,2,3,4],[5,2,8, 7])

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### **Multiple Subplots On The Same Figure**

# %%
f, ax = plt.subplots(nrows=2,ncols=2)
# or
# f, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=2,ncols=2)

# or,
# fig = plt.figure()
# ax1 = plt.subplot(221) #2x2 grid, first plot
# ax2 = plt.subplot(222)
# ax3 = plt.subplot(223)
# ax4 = plt.subplot(224)
# ax1.plot(x,y) etc..

### Note: orientation is given by [row, col]
ax[0,0].plot(x, y)
ax[1,0].scatter(x, y)
ax[0,1].hist(values)
ax[1,1].barh(x,np.abs(y))

# add some auto-spacing
plt.tight_layout();

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### Custom Subplot Grids

# %%
# We can make arbitrarly complicated subplot grids with plt.subplot2grid
# example taken from Python Bootcamp https://github.com/profjsb/python-bootcamp

x = np.linspace(0,2*np.pi,10000)
y1 = np.sin(x)
y2 = np.sin(x)**2

f = plt.figure()

# subplot2grid(grid_shape, loc_in_grid, rowspan=1, colspan=1)
# 3 x 3 grid

# Specify the grid
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3) # spans three cols
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2) # 3 
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))

# remove tick labels on all axes
for ax in f.axes:
    for t in ax.get_xticklabels()+ax.get_yticklabels():
        t.set_visible(False)
    

# make a different kinds of plots!
ax1.plot(x, y1)
ax2.hist(y1)
ax3.scatter(x,y1)
ax4.boxplot(y1)
ax5.loglog(x, y1)

# Add titles
ax1.set_title('This')
ax3.set_title('plot')
ax5.set_title('rules!')
f.suptitle('Grid layout, yeah!',fontsize=20, y=1.1) # y location

f.tight_layout()    # great command for adding white space
                    # between plots

# %% [markdown]
# <hr style="border: 3px solid#1f77b4;" />
#
# ### Quick Asside -- Hello Plotly: Processing **Matplotlib with plot_mpl()**
#
# > **Option 1:** Register an account with Ploty and get API keys https://plot.ly
#
# > **Option 2:** Download static image to desired path -- more on this bellow.

# %%
### Option 1 ###
# -> settings -> API Keys
import plotly.plotly as py
import plotly.tools as tls


py.sign_in('ehcastroh', 'QzmGAIhRuVzcqRaFW0w6') #(user_name, api_key)

# url object
mat_plotly = py.plot_mpl(f)
#print(mat_plotly)

# iframe object
plt_iframe = tls.get_embed(mat_plotly);
#print(plt_iframe)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ehcastroh/12.embed" height="525" width="100%"></iframe>

# %%
### Display plotly iframe within HTML ###
from IPython.display import HTML
HTML("""<div style="text-align: center"><iframe width="70%" height="500" src="https://plot.ly/~ehcastroh/12.embed" frameborder="10"></iframe>
     </div>
     <div style="text-align: center"><strong>Note: </strong> setting frameborder to 0 will clear the frame, as well as the navigation bar.</div>
     """) 

# or
# you can also import the iframe package and display it without using html -- each have their benefits ;)
# or
# you can offline plot and download an image to be used as desired.
# Out:
# <div style="text-align: center"><iframe width="70%" height="500" src="https://plot.ly/~ehcastroh/12.embed" frameborder="10"></iframe>
#      </div>
#      <div style="text-align: center"><strong>Note: </strong> setting frameborder to 0 will clear the frame, as well as the navigation bar.</div>

# %% [markdown]
# <br>
#
# ### Quick Aside Done -- Good Bye Plotly, for now...
# <hr style="border: 3px solid#1f77b4;" />

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### Plot **Styling:** Labels, Text, Legend & Changing Colors

# %%
# Three different line plots on same axes

N = 50 
x = np.arange(1,N+1)
y = np.random.randn(N)

fig, ax = plt.subplots()

# select colots
ax.plot(x,y,color='green', linestyle=':', label='line 1',linewidth = 2.5)
ax.plot(x,y*2,color='orange', linestyle='--', label = 'line 2')
ax.plot(x,y+4,color='black',marker='o', label = 'line 3')

ax.legend(loc=4) # location of legend is an integer, 
# for text to be correct in the legend the plots need a label

# add plot LaTex style title, with line breaks (To r'LaTex' or not to r'LaTex')
ax.set_title('3 Graphs (g): $\sum^3_i= g_i$\nsubtitle\n',
             color='blue',fontweight='bold',fontsize=26) 


ax.set_xlabel('x label') # add xlabel
ax.set_ylabel('y label'); # add ylabel

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### Customize **Legend & Axis Range**

# %%
fig, ax = plt.subplots()

# ax.plot() returns a line object that we can assign to variables
# Note comma, in order to unpack tuple object

l1, = ax.plot(x,y,color='green', linestyle=':', label='line 1',linewidth = 2.5) 

l2, = ax.plot(x,y*2,'y--', label = 'line 2')
l3, = ax.plot(x,y+4,color='black', linestyle='--',marker='o', label = 'line 3')

# Custom axis range
#ax.set_ylim(-6,8)
#ax.set_xlim(0,9)

# Custom legend
ax.legend(handles=[l1, l3], labels=['green vert', 'black dash dot'],
              loc=[0.6,0.92],frameon=True,numpoints=3);

# %% [markdown]
# ___

# %%
## another example of concept

fig, ax1 = plt.subplots()

N = 100 # number of samples

err=np.random.randn(N)*5

x=np.linspace(0,10,N)

y=12+x*3.5+err
y2 = np.sin(2 * np.pi * x)

# plot
ax1.set_xlim(0,10)
l1 = ax1.scatter(x,y,color='blue',label='scatter')
ax1.set_ylabel('line',color='blue')
ax1.tick_params('y',colors='blue')


ax2 = ax1.twinx() # create second axis for y2
l2, = ax2.plot(x, y2, color='red',label='$sin(x)$')
ax2.set_ylabel('sin', color='red')
ax1.set_xlim(0,10)
ax2.tick_params('y', colors='red')

plt.legend((l1,l2),('scatter','$sin(x)$'),loc=[0.8,1]);

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### Two Axes **Sharing x-Axis, Saving & Displaying Plots**

# %%
# Generate data
x = np.linspace(0,2*np.pi,51)
y1 = np.sin(x)
y2 = 2*np.sin(x)**2

# %%
# Create two subplots, on two rows with two axes ax1 and ax2
f, (ax1, ax2) = plt.subplots(2, 1,sharex=True)

#f, (ax1, ax2) = plt.subplots(1,2) # Would be vertical

ax1.plot(x,y1)
ax2.plot(x + np.pi,y2)
# show ticks
plt.xticks(np.linspace(0,3*np.pi,7),
           ('0','$\pi/2$','$\pi$','$3\pi/2$','$2\pi$','$5\pi/2$','$3\pi$')); 

f.suptitle('Sharing x-axis'); # Title for both subplots

# %%
# Save fig to desired path
abs_path = '/home/ehch/SCET/Data-X/02c-tools-data-visualizations/data/'

f.savefig(abs_path + 'abs_path_fig.png') # easy, png, svg, pdf, etc work
f.savefig('data/rel_path_fig.svg')
# it will take on the file format

# %%
# %ls # list files in your present working directory
# Out:
# breakout-L4/  fig.svg
# data/         periodic_table.html
# datafig.png   README.md
# datafig.svg   resources/
# example.jpg   visualization-intro-w-matplotlib-seaborn-plotly-v3.ipynb
# fig.png

# %%
# display plot
from IPython.display import Image
Image(filename='data/abs_path_fig.png')

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### **Display Images** Using IPython

# %%
# display RANDOM image file
from IPython.display import Image
Image(filename='example.jpg')

# %%
# explore non-visual information in image
img = Image(filename='example.jpg')
print(type(img))
print(dir(img))
# Out:
# <class 'IPython.core.display.Image'>
# ['_ACCEPTABLE_EMBEDDINGS', '_FMT_GIF', '_FMT_JPEG', '_FMT_PNG', '_MIMETYPES', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_check_data', '_data_and_metadata', '_find_ext', '_mimetype', '_read_flags', '_repr_html_', '_repr_jpeg_', '_repr_mimebundle_', '_repr_png_', '_retina_shape', '_show_mem_addr', 'data', 'embed', 'filename', 'format', 'height', 'metadata', 'reload', 'retina', 'unconfined', 'url', 'width']

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### Adjusting Opacity, Markers & Add A Color Bar

# %%
N=50

x = np.random.randn(N)
y = np.random.randn(N)
colors = np.random.rand(N)
sizes = N*10 * np.random.rand(100)

# cmap gives color scheme, alpha controls opacity
plt.scatter(x, y, c=colors, s=sizes, alpha=0.4, cmap='nipy_spectral')
plt.colorbar(); #this will add a color bar to the right

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### Matplotlib **3d Plot**

# %%
# Axes 3D needed to set projection='3d'
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data, spherical coordinates
u = np.linspace(0, .5*np.pi, 100)
v = np.linspace(0, 2*np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))


# Plot the surface
ax.plot_surface(x, y, z, color='r');

# %% [markdown]
# <hr style="border: 1px solid#0B0B0B;" />
#
# ### Change **Plot Styling**
#
# > Some common styles: [matplotlib style gallery](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html)

# %%
# increase the figure size for all plots

IPython_default = plt.rcParams.copy() # save default styling

# %%
data1 = np.random.randint(-10,5,400)
data2 = np.random.randint(-10,11,400)
data3 = np.random.randint(-10,11,400)

### For R Lovers ###
plt.style.use('ggplot')
plt.figure()
plt.hist([data1,data2,data3])
plt.title('ggplot')

### For Nate Silver Fans ###
plt.style.use('fivethirtyeight')
plt.figure()
plt.hist([data1,data2,data3])
plt.title('fivethirteight')

### For Linux Kernel Developers ###
plt.style.use('dark_background')
plt.figure()
plt.hist([data1,data2,data3])
plt.title('dark-background')

### Alex's Prefered Scheme ###
plt.style.use('seaborn-white') # classic MATLAB styling not that pretty
plt.figure()
plt.hist([data1,data2,data3])
plt.title('seaborn-white (alex favorite!)');

# %%
# restore defaults

plt.rcParams.update(IPython_default);

# %% [markdown]
# <a id='Part_2'></a>
# <hr style="border: 3px solid#0B0B0B;" />
#
# ## **Part 2: Seaborn**
#
# **General Information**
#
# > 1. __Load Matplotlib:__ https://matplotlib.org/faq/installing_faq.html#installation
#
# > 2. __Matplotlib Object Hierarchy:__ https://matplotlib.org/tutorials/introductory/usage.html
#
# > 3. __Approaches to Matplotlib__

# %%
from IPython.display import *
# play video using IPython
HTML('<div style="text-align: center"><iframe width="840" height="473" src="https://www.youtube.com/embed/ohsvE8UdEd0?controls=0&amp;start=337&end=352" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>')
# Out:
# <div style="text-align: center"><iframe width="840" height="473" src="https://www.youtube.com/embed/ohsvE8UdEd0?controls=0&amp;start=337&end=352" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>

# %% [markdown]
# # Seaborn and pandas
# **Note:** Anaconda does not come with seaborn, please install it in your virtual environment by running:
# ```bash
# conda intall seaborn
# ```
#
# - **seaborn:** Mostly used for statistical plotting, and better graphics.
# - **pandas:** Mostly used for quick plotting of DataFrames and time series

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("iris") # load classic ML dataset
df.head()

# %%
df.plot();

# %%
df.plot.box();

# %%
df.mean().plot.pie();

# %%
sp = list(df['species'].unique())
cols = list(['g','b','y'])
colors = dict(zip(sp,cols))
colors

# %%
df.plot.scatter('sepal_length','sepal_width',c=df['species'].apply(lambda x: colors[x]))

# %%
sns.pairplot(df, hue='species', size=2.5)

# %%
sns.distplot(df['sepal_length'],color='orange');

# %%
sns.boxplot(data=df);

# %% [markdown]
# <a id='Part_2'></a>
# <hr style="border: 2px solid#1A2D3E;" />
#
# ## **Part 2: Seaborn**
#
# **General Information**
#
# > 1. __Load Matplotlib:__ https://matplotlib.org/faq/installing_faq.html#installation
#
# > 2. __Two Plotting Approaches:__ https://cloud.google.com/community/tutorials/understanding-oauth2-and-deploy-a-basic-auth-srv-to-cloud-functions
#
# > 3. __Connect to Instance and Set-Up SSH:__ https://cloud.google.com/compute/docs/instances/connecting-to-instance
#
# > 4. __Set Firewall:__ https://cloud.google.com/vpc/docs/firewalls
#
# > 5. __Enable Video Intelligence API:__ https://cloud.google.com/video-intelligence/docs/
#
# > 6. __Reserve a Static IP Address:__ https://cloud.google.com/compute/docs/ip-addresses/reserve-static-external-ip-address

# %% [markdown]
# <a id='Part_3'></a>
# <hr style="border: 2px solid#1A2D3E;" />
#
# ## **Part 3: Plotly**
#
# **General Information**
#
# > 1. __Load Matplotlib:__ https://matplotlib.org/faq/installing_faq.html#installation
#
# > 2. __Two Plotting Approaches:__ https://cloud.google.com/community/tutorials/understanding-oauth2-and-deploy-a-basic-auth-srv-to-cloud-functions
#
# > 3. __Connect to Instance and Set-Up SSH:__ https://cloud.google.com/compute/docs/instances/connecting-to-instance
#
# > 4. __Set Firewall:__ https://cloud.google.com/vpc/docs/firewalls
#
# > 5. __Enable Video Intelligence API:__ https://cloud.google.com/video-intelligence/docs/
#
# > 6. __Reserve a Static IP Address:__ https://cloud.google.com/compute/docs/ip-addresses/reserve-static-external-ip-address

# %% [markdown]
# <hr style="border: 10px solid#1A2D3E;" />

# %% [markdown]
# <a id='Appendix_I'></a>
# ## Appendix I: Resources and references to material we won't cover in detail
#
#
# > * **Slide Presentations Within Jupyter Using RISE:** https://pypi.org/project/rise/
#
# > * **IPython Display and Outputs:** https://nbviewer.jupyter.org/github/ipython/ipython/blob/38fd9b71f62c6c726871875d3bacfbdb4ffba13c/examples/IPython%20Kernel/Rich%20Output.ipynb#Audio
#
# > * **Stanford's Data Visualization Techniques:** https://magrawala.github.io/cs448b-fa18/
#
# > * **Data Driven Visual Story Telling - Edward Tufte:** https://www.edwardtufte.com/tufte/
#
# <br>
#
# <hr style="border: 2px solid#1A2D3E;" />

# %% [markdown]
# <a id='Appendix_II'></a>
# ## Appendix II: Gallery of visualization examples
#
#
# # Other packages you can check out
# Interactive plots
# - [Bokeh](https://bokeh.pydata.org/)
# - [Plotly](https://plot.ly/)
#
# Declarative plotting
# - [Altair](https://altair-viz.github.io/)
# - [Vega](https://vega.github.io/vega/)
#
#
# https://pypi.org/project/rise/
#
# <br>
#
# ___

# %%
## ANATOMY OF A FIGURE
from IPython.display import *
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter


np.random.seed(19680801)

X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)


def minor_tick(x, pos):
    if not x % 1.0:
        return ""
    return "%.2f" % x

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

ax.plot(X, Y1, c=(0.25, 0.25, 1.00), lw=2, label="Blue signal", zorder=10)
ax.plot(X, Y2, c=(1.00, 0.25, 0.25), lw=2, label="Red signal")
ax.plot(X, Y3, linewidth=0,
        marker='o', markerfacecolor='w', markeredgecolor='k')

ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")

ax.legend()


def circle(x, y, radius=0.15):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)


def text(x, y, text):
    ax.text(x, y, text, backgroundcolor="white",
            ha='center', va='top', weight='bold', color='blue')


# Minor tick
circle(0.50, -0.10)
text(0.50, -0.32, "Minor tick label")

# Major tick
circle(-0.03, 4.00)
text(0.03, 3.80, "Major tick")

# Minor tick
circle(0.00, 3.50)
text(0.00, 3.30, "Minor tick")

# Major tick label
circle(-0.15, 3.00)
text(-0.15, 2.80, "Major tick label")

# X Label
circle(1.80, -0.27)
text(1.80, -0.45, "X axis label")

# Y Label
circle(-0.27, 1.80)
text(-0.27, 1.6, "Y axis label")

# Title
circle(1.0, 4.13)
text(1.60, 3.93, "Title")

# Blue plot
circle(1.75, 2.80)
text(1.75, 2.60, "Line\n(line plot)")

# Red plot
circle(1.20, 0.60)
text(1.20, 0.40, "Line\n(line plot)")

# Scatter plot
circle(3.20, 1.75)
text(3.20, 1.55, "Markers\n(scatter plot)")

# Grid
circle(3.00, 3.00)
text(3.00, 2.80, "Grid")

# Legend
circle(3.70, 3.80)
text(3.70, 3.60, "Legend")

# Axes
circle(0.5, 0.5)
text(0.5, 0.3, "Axes")

# Figure
circle(-0.3, 0.65)
text(-0.3, 0.45, "Figure")

color = 'blue'
ax.annotate('Spines', xy=(4.0, 0.35), xycoords='data',
            xytext=(3.3, 0.5), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.annotate('', xy=(3.15, 0.0), xycoords='data',
            xytext=(3.45, 0.45), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.text(4.0, -0.4, "Made with http://matplotlib.org",
        fontsize=10, ha="right", color='.5')

plt.show()

# %%
# import libraries
from pylab import *
from scipy.stats import norm
import pandas as pd
import numpy as np


### NOTE: Regarding plotly
"""
The following code is writen to function with plotly > 2.7.0 but < +3.0.0
pip uninstall plotly
pip install plotly==2.7.0
"""
import plotly
import plotly.plotly as py
import plotly.tools as tls              # for mpl, config, etc.
import plotly.offline as offline
import plotly.graph_objs as go
from plotly.graph_objs import *         # __all__ is safely defined
import plotly.figure_factory as ff
from scipy.spatial import Delaunay
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot


from datetime import date

# pretty colors
import seaborn as sns
# pretty print for json objects
import pprint as pp

from imp import reload


plotly.__version__

# %%
# sign-in requires a plotly id - https://plot.ly
# -> settings -> API Keys
py.sign_in('eltheit', '9xvTwFTtW9QtjCdNrL7j') #(user_name, api_key)


#py.iplot(pt, filename='periodic_table')

offline.plot(pt,image='png',filename="periodic_table", show_link=False)

# %% [markdown]
# ## Matplotlib Galleries

# %%
### MATPLOTLIB GALLERY ###
from IPython.display import *
HTML('<div style="text-align: center"><iframe width="70%" height="600" src="https://matplotlib.org/1.4.3/gallery.html#" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>')

# %% [markdown]
# <hr style="border: 1px solid#1A2D3E;" />

# %%
### THE PYTHON GRAPH GALLERY ###
HTML('<div style="text-align: center"><iframe width="70%" height="600" src="https://python-graph-gallery.com/" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>')

# %% [markdown]
# <hr style="border: 1px solid#1A2D3E;" />
#
# ## Seaborn Gallery

# %%
### SEABORN GALLERY ###
HTML('<div style="text-align: center"><iframe width="70%" height="600" src="https://seaborn.pydata.org/examples/index.html" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>')

# %% [markdown]
# <hr style="border: 1px solid#1A2D3E;" />
#
# ## Plotly Gallery

# %%
### PLOTLY PYTHON ###
HTML('<div style="text-align: center"><iframe width="70%" height="600" src="https://plot.ly/python/" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>')

# %% [markdown]
# <hr style="border: 1px solid#1A2D3E;" />
#
# ## General Visualization Information

# %%
### http://www.visual-literacy.org/periodic_table/periodic_table.pdf ###
HTML('<div style="text-align: center"><iframe width="90%" height="600" src="http://www.visual-literacy.org/periodic_table/periodic_table.html" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>')

# %% [markdown]
# <hr style="border: 3px solid#0B0B0B;" />
#
# ## HTML, CSS, and Javascript

# %%
### http://www.visual-literacy.org/periodic_table/periodic_table.pdf ###
WE_ARE_DONE_todays_attendance_code = HTML("""
    <table role="module" border="0" cellpadding="0" cellspacing="0" width="100%" height="500" style="table-layout:fixed">
        <tbody><tr> 
            <!--padding: t,r,b,l-->
            <td style="background-color:#FFFFFF;padding:0px 0px 0px 0px;text-align:center" height="100%" width="70%" valign="center" bgcolor="#ffffff">
                <div style="text-align:center; padding:0px 0px 0px">

                    <iframe width="100%" height="500" src="https://www.youtube-nocookie.com/embed/6OEynMECez4?&controls=0&autoplay=1&vq=hd1080" 
                        frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen>
                    </iframe>
                    
                </div>
                <img src= "http://oi64.tinypic.com/o858n4.jpg" align="center" width="98%" bgcolor="#FFFFFF" style="padding:0px 0px 0px 28px; align:center">
            </td>
            <td style="background-color:#000000;padding:0px 30px 0px 30px ;text-align:left" height="100%" width="30%" valign="center" bgcolor="#7FFFD4">
                                
                <div style="padding:0px 20px 0px 0px;text-align:right; box-sizing:content-box;margin-top:0px; margin-bottom:0px;
                    font-style:normal;font-variant-ligatures:normal;font-variant-caps:normal;font-weight:400;
                    font-family:'Open Sans','Helvetica Neue', Helvetica, Arial, sans-serif;font-size:22px;color:rgb(74,74,74)">&nbsp;
                    <span style="font-size:40px; color: #B57EDC">TODAY'S ATTENDANCE CODE:</span>
                </div>
                <div style="padding:0px 20px 0px 0px;text-align:right; box-sizing:content-box;margin-top:40px; margin-bottom:0px;
                    font-style:normal;font-variant-ligatures:normal;font-variant-caps:normal;font-weight:800;
                    font-family:'Open Sans','Helvetica Neue', Helvetica, Arial, sans-serif;font-size:22px;color:rgb(74,74,74)">&nbsp;
                        <span style="font-size:40px; color: #FFBF00">SOMESUG LKJSDJO</span>
                </div>
                
            </td>
        </tr></tbody>
    </table>
    """
    )

# %%
WE_ARE_DONE_todays_attendance_code

# %%
LINKEDIN: EHCASTROH
EMAIL   : EHCASTROH@BERKELEY.EDU
TWITTER : @EHCASTROH
